# %%
# Import lớp Image
from PIL import Image
from imgtools import *

# %%
# Đường dẫn ảnh
my_path = 'C:\\img/01.jpg'

# %%
# Đọc ảnh 
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=235x288>
