# %%
# Import lớp Image
from PIL import Image
from imgtools import *

# %%
# Thư mục chứa hình ảnh
my_dir = 'C:/img'

# %%
# Đọc nhiều ảnh
imgs =  get_image_list(my_dir)

# %%
# Hiển thị toàn bộ ảnh bằng hàm display

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (235, 288)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=235x288>
# (236, 460)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x460>
# (474, 842)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x842>
# (236, 419)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x419>
# (236, 419)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x419>
# (236, 421)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x421>
